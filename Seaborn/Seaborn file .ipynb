# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
x = [1,2,3,4,5,6,7,8]
y = [50,20,30,40,90,100,20,10]
data = pd.DataFrame({"Days":x,"people":y})
data.head()
# Out:
#    Days  people
# 0     1      50
# 1     2      20
# 2     3      30
# 3     4      40
# 4     5      90

# %%
sns.lineplot(x="Days",y="people",data= data)
# Out:
# <Axes: xlabel='Days', ylabel='people'>

# %%
df = pd.read_csv("tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(x="day", y="total_bill",hue = "sex" ,data= df,style="time",palette="flare")
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="total_bill",y = "tip",data=df,hue = 'sex',palette="spring",saturation=0.9)
plt.show()

# %%
sns.barplot(y ="total_bill",x ="tip",data=df,hue = "sex",palette="spring",saturation=0.9)
plt.show()

# %%
sns.histplot(x="total_bill",y ="tip",data=df)
plt.show()
