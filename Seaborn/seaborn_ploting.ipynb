# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data=pd.read_csv("tips.csv")
print(data)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(x="total_bill",y ="tip",data=data,hue="sex",palette="spring")
plt.show()

# %%
plt.scatter(data['day'],data['tip'])
plt.title("Scatter plot")
plt.xlabel("Day")
plt.ylabel("Tip")
plt.show()

# %%
x=data['day']
y=data['tip']
plt.scatter(x,y)
plt.title("Scatter")
plt.xlabel("Day")
plt.ylabel("Tip")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns .scatterplot(x='day',y='tip',data= data,hue="sex")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns .scatterplot(x='day',y='tip',data= data,hue="time")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns .scatterplot(x='day',y='tip',data= data,hue="day")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns .scatterplot(x='day',y='tip',data= data,hue="tip")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.plot(data['sex'] , data['total_bill'])
plt.show()

# %%
import seaborn as sns
sns.lineplot(x='sex', y='total_bill', data= data)
plt.show()

# %%
import seaborn as sns
sns.lineplot(x='day', y='tip', data= data)
plt.show()

# %%
import seaborn as sns
sns.lineplot(x='total_bill', y='tip', data= data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.barplot(x='day',y='tip', data = data,hue='sex')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.barplot(x='day',y='tip', data = data,hue='time')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.barplot(x='day',y='tip', data = data ,hue='size')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
plt.hist(data["total_bill"],10, color='yellow')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.histplot(x="total_bill",data=data,hue='sex', kde=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#declaring data
data=[44,45,40,41,39]
key =['sun','Mon','THE','THU','FRI']
plt.pie(data,labels = key )
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data =pd.read_csv("tips.csv")
print(data)
import seaborn as sns
sns.boxplot(data=data,y='tip',x='day')
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd
data =pd.read_csv("tips.csv")
print(data)
import seaborn as sns
sns.boxplot(data=data,x='sex',y='tip')
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#THAT ALL
