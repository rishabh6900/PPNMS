# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = [1,2,3,4,5,6,7,8]
y = [50,20,30,40,90,100,20,10]
df = pd.DataFrame({"Days":x,"people":y})
df.head(4)
# Out:
#    Days  people
# 0     1      50
# 1     2      20
# 2     3      30
# 3     4      40

# %%
#Line plot
sns.lineplot(x="Days",y="people",data=df)
plt.show()

# %%
df1 = pd.read_csv("tips.csv")
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.load_dataset("tips")
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(x="day", y="total_bill",hue = "sex" ,data= df1,style="time",palette="flare")
# sns.show()
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#bar plot
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x ="total_bill",y ="tip",data=df1,hue = "sex",palette="spring",saturation=0.9 )
plt.show()

# %%
sns.barplot(y ="total_bill",x ="tip",data=df1,hue = "sex",palette="spring",saturation=0.9)
plt.show()

# %%
#hist plot
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(x="total_bill",y ="tip",data=df1)
plt.show()

# %%
sns.histplot(x="total_bill",y ="tip",data=df1,hue="sex",palette="spring")
plt.show()

# %%
sns.histplot(x="total_bill",data=df1,hue='sex',edgecolor = "green", kde=True,)
plt.show()

# %%
#Scatter plot

# %%
sns.scatterplot(x="total_bill",y ="tip",data=df1,hue = "sex")
plt.show()

# %%
sns .scatterplot(x='day',y='tip',data=df1,hue="tip")
plt.show()

# %%
#heatmap plot
data = np.random.randint(low = 1,high =100,size=(10,10))
print(data)
# Out:
# [[63 28 19 65 53 60 57 35 62 47]
#  [36 71 46 40 12 64 15 70  9 78]
#  [45 41 37 54 63  1 27 52 29 40]
#  [34 92 74 57 82 67 66 40  9 19]
#  [82 67 51 63 31 18 27  1 72 16]
#  [ 9 26 71 15 84 11 59  1 96 61]
#  [91 70 30 27 20 13 49 70 44  6]
#  [35 13 63 35 59 30 75 35 31 97]
#  [87 23 34 69 97 32 43 27 84 33]
#  [81 39 52 47 98 48 19 43 38 84]]

# %%
sns.heatmap(data= data , linewidth = "4", linecolor = "pink" , annot = True)
plt.show()

# %%
sns.heatmap(data= data , linewidth = "4", linecolor = "pink" ,cmap = "GnBu", annot = True)
plt.show()

# %%
#count plot
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x = "tip" ,data = df1,color = "pink")
plt.show()

# %%
sns.countplot(x = "sex" ,data = df1, color = "green")
plt.show()

# %%
sns.countplot(y = "sex",data = df1)
plt.show()

# %%
sns.countplot(x ="sex",data = df1,hue="smoker")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#violin plot
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.violinplot(x = df1["total_bill"])
plt.show()

# %%
sns.violinplot(x = "total_bill",y ="tip",data= df1)
plt.show()

# %%
sns.violinplot(x ="sex",y ="tip",data= df1)
plt.show()

# %%
sns.violinplot(x ="sex",y ="tip",data= df1,hue = "day")
plt.show() #meadin

# %%
from posixpath import split
sns.violinplot(x ="day",y ="tip",data = df1,hue = "sex",split = True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#Boxplot
sns.boxplot(x = df1["total_bill"])
plt.show()

# %%
sns.boxplot(x = "total_bill",y="day",data= df1)
plt.show() # meadin

# %%
sns.boxplot(x = "sex",y="tip",data= df1, hue = "smoker")
plt.show() # meadin

# %%
sns.set(style ="whitegrid")
sns.boxplot(x = df1["tip"],data = df1)
# Out:
# <Axes: xlabel='tip'>

# %%
#pairplot
dff = pd.read_csv("Iris.csv")
dff.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(data =dff,height = 1.5)

# %%
sns.pairplot(data =dff,height = 1.5,hue = "Species",palette="viridis")
plt.show()

# %%
sns.pairplot(data =dff,height = 1.5,hue = "Species",palette="viridis",diag_kind ="hist")
plt.show()

# %%
#catplot

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x ="sex",y ="tip" ,data =df1)
plt.show()

# %%
sns.catplot(x ="sex",y ="tip" ,data =df1,kind = "bar")
plt.show()

# %%
sns.catplot(x ="sex",y ="tip" ,data =df1,kind = "violin", hue = "smoker")
plt.show()

# %%
#strip plot

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.stripplot(x=df1["tip"])
# Out:
# <Axes: xlabel='tip'>

# %%
sns.stripplot(x="day",y = "tip",data = df1, hue ="sex")
plt.show()

# %%
sns.stripplot(x="day",y = "tip",data = df1,hue ="sex",jitter=0.2,dodge=True, marker="*", size = 10)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#APE63 miss

# %%
#kde plot

# %%
x = np.random.randn(100)
y = np.random.randn(100)
sns.kdeplot(x)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(x, shade = True,color = "red")
# Out:
# C:\Users\rajna\AppData\Local\Temp\ipykernel_13120\1688336899.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x, shade = True,color = "red")
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Sample data
x = np.random.normal(0, 1, 1000)
y = np.random.normal(0, 1, 1000)

# Correct usage
sns.kdeplot(x=x, y=y, shade=True, color="violet")  # Use named parameters

plt.show()
# Out:
# C:\Users\rajna\AppData\Local\Temp\ipykernel_13120\400708794.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=x, y=y, shade=True, color="violet")  # Use named parameters

# %%
# sns.kdeplot(x,y, shade = True,color= "violet")

# %%
sns.kdeplot(data=df1, x='total_bill', y='tip', shade=True, color="violet")
# Out:
# C:\Users\rajna\AppData\Local\Temp\ipykernel_13120\3276512952.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df1, x='total_bill', y='tip', shade=True, color="violet")
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(data=dff, x='SepalLengthCm', y='PetalLengthCm', shade=True, color="violet")
# Out:
# C:\Users\rajna\AppData\Local\Temp\ipykernel_13120\1525998676.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=dff, x='SepalLengthCm', y='PetalLengthCm', shade=True, color="violet")
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
#Swarm plot
sns.swarmplot(x =df1["day"], y = df1["total_bill"], )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y ="total_bill",data =df1,hue = "smoker" ,dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# styling plots #miss

# %%
                          #thank you
